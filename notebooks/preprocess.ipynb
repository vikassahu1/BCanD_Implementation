# %%
import pandas as pd
import numpy as np
import os

# %%
# %pip install kagglehub

import kagglehub

# Download latest version
path = kagglehub.dataset_download("kmader/mias-mammography")

print("Path to dataset files:", path)
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.2.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: packaging in c:\users\vikas\documents\projects\machine_learning_projects\venv\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: requests in c:\users\vikas\documents\projects\machine_learning_projects\venv\lib\site-packages (from kagglehub) (2.32.3)
# Collecting tqdm (from kagglehub)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vikas\documents\projects\machine_learning_projects\venv\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vikas\documents\projects\machine_learning_projects\venv\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vikas\documents\projects\machine_learning_projects\venv\lib\site-packages (from requests->kagglehub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vikas\documents\projects\machine_learning_projects\venv\lib\site-packages (from requests->kagglehub) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\vikas\documents\projects\machine_learning_projects\venv\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.2.9-py3-none-any.whl (39 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, kagglehub
# Successfully installed kagglehub-0.2.9 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\Vikas\Documents\Projects\machine_learning_projects\venv\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kmader/mias-mammography?dataset_version_number=3...
# 100%|██████████| 312M/312M [05:07<00:00, 1.06MB/s]
# Extracting model files...
# Path to dataset files: C:\Users\Vikas\.cache\kagglehub\datasets\kmader\mias-mammography\versions\3

# %%
filepath = "C:\\Users\\Vikas\\.cache\\kagglehub\\datasets\\kmader\\mias-mammography\\versions\\3\\Info.txt"

column_names = [
    'Reference_Number', 'Background_Tissue', 'Abnormality_Class', 'Severity_Abnormality', 'X', 'Y', 'RADIUS' 
]
mias_df = pd.read_csv(filepath, sep=" ").drop('Unnamed: 7',axis=1)
mias_df.columns = column_names
mias_df
# Out:
#     Reference_Number Background_Tissue Abnormality_Class Severity_Abnormality  \
# 0             mdb001                 G              CIRC                    B
# 1             mdb002                 G              CIRC                    B
# 2             mdb003                 D              NORM                  NaN
# 3             mdb004                 D              NORM                  NaN
# 4             mdb005                 F              CIRC                    B
# ..               ...               ...               ...                  ...
# 325           mdb318                 D              NORM                  NaN
# 326           mdb319                 D              NORM                  NaN
# 327           mdb320                 D              NORM                  NaN
# 328           mdb321                 D              NORM                  NaN
# 329           mdb322                 D              NORM                  NaN
#
#          X      Y  RADIUS
# 0    535.0  425.0   197.0
# 1    522.0  280.0    69.0
# 2      NaN    NaN     NaN
# 3      NaN    NaN     NaN
# 4    477.0  133.0    30.0
# ..     ...    ...     ...
# 325    NaN    NaN     NaN
# 326    NaN    NaN     NaN
# 327    NaN    NaN     NaN
# 328    NaN    NaN     NaN
# 329    NaN    NaN     NaN
#
# [330 rows x 7 columns]

# %%
# Replacing NaN
mias_df['Severity_Abnormality'] = mias_df['Severity_Abnormality'].fillna('N')
mias_df.drop_duplicates(subset='Reference_Number', inplace=True)
mias_df.set_index('Reference_Number', inplace=True)
mias_df
# Out:
#                  Background_Tissue Abnormality_Class Severity_Abnormality  \
# Reference_Number
# mdb001                           G              CIRC                    B
# mdb002                           G              CIRC                    B
# mdb003                           D              NORM                    N
# mdb004                           D              NORM                    N
# mdb005                           F              CIRC                    B
# ...                            ...               ...                  ...
# mdb318                           D              NORM                    N
# mdb319                           D              NORM                    N
# mdb320                           D              NORM                    N
# mdb321                           D              NORM                    N
# mdb322                           D              NORM                    N
#
#                       X      Y  RADIUS
# Reference_Number
# mdb001            535.0  425.0   197.0
# mdb002            522.0  280.0    69.0
# mdb003              NaN    NaN     NaN
# mdb004              NaN    NaN     NaN
# mdb005            477.0  133.0    30.0
# ...                 ...    ...     ...
# mdb318              NaN    NaN     NaN
# mdb319              NaN    NaN     NaN
# mdb320              NaN    NaN     NaN
# mdb321              NaN    NaN     NaN
# mdb322              NaN    NaN     NaN
#
# [322 rows x 6 columns]

# %%
mias_df
# Out:
#                  Background_Tissue Abnormality_Class Severity_Abnormality  \
# Reference_Number
# mdb001                           G              CIRC                    B
# mdb002                           G              CIRC                    B
# mdb003                           D              NORM                    N
# mdb004                           D              NORM                    N
# mdb005                           F              CIRC                    B
# ...                            ...               ...                  ...
# mdb318                           D              NORM                    N
# mdb319                           D              NORM                    N
# mdb320                           D              NORM                    N
# mdb321                           D              NORM                    N
# mdb322                           D              NORM                    N
#
#                       X      Y  RADIUS
# Reference_Number
# mdb001            535.0  425.0   197.0
# mdb002            522.0  280.0    69.0
# mdb003              NaN    NaN     NaN
# mdb004              NaN    NaN     NaN
# mdb005            477.0  133.0    30.0
# ...                 ...    ...     ...
# mdb318              NaN    NaN     NaN
# mdb319              NaN    NaN     NaN
# mdb320              NaN    NaN     NaN
# mdb321              NaN    NaN     NaN
# mdb322              NaN    NaN     NaN
#
# [322 rows x 6 columns]

# %%
# Setup of scan directory to take all images
scan_directory = "C:\\Users\\Vikas\\.cache\\kagglehub\\datasets\\kmader\\mias-mammography\\versions\\3\\all-mias"

# %%
scan_df = mias_df.copy()
scan_df['scan_path'] = scan_df.index.map(lambda x: os.path.join(scan_directory, f"{x}.pgm"))

scan_df.head()
# Out:
#                  Background_Tissue Abnormality_Class Severity_Abnormality  \
# Reference_Number
# mdb001                           G              CIRC                    B
# mdb002                           G              CIRC                    B
# mdb003                           D              NORM                    N
# mdb004                           D              NORM                    N
# mdb005                           F              CIRC                    B
#
#                       X      Y  RADIUS  \
# Reference_Number
# mdb001            535.0  425.0   197.0
# mdb002            522.0  280.0    69.0
# mdb003              NaN    NaN     NaN
# mdb004              NaN    NaN     NaN
# mdb005            477.0  133.0    30.0
#
#                                                           scan_path
# Reference_Number
# mdb001            C:\Users\Vikas\.cache\kagglehub\datasets\kmade...
# mdb002            C:\Users\Vikas\.cache\kagglehub\datasets\kmade...
# mdb003            C:\Users\Vikas\.cache\kagglehub\datasets\kmade...
# mdb004            C:\Users\Vikas\.cache\kagglehub\datasets\kmade...
# mdb005            C:\Users\Vikas\.cache\kagglehub\datasets\kmade...
